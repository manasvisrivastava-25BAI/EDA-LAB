# %% [markdown]
# <a href="https://colab.research.google.com/github/manasvisrivastava-25BAI/EDA-LAB/blob/main/exp5_04_08_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('/content/drive/MyDrive/fraudTest.csv')
df2 = pd.read_csv('/content/drive/MyDrive/fraudTrain.csv')

# %%
marks = [120, 132, 154, 164, 168, 177, 189, 190, 193, 194, 194, 197, 199, 200]
bins  = [118, 125, 160, 180, 200]
category = pd.cut(marks, bins)
category
# Out:
# [(118, 125], (125, 160], (125, 160], (160, 180], (160, 180], ..., (180, 200], (180, 200], (180, 200], (180, 200], (180, 200]]
# Length: 14
# Categories (4, interval[int64, right]): [(118, 125] < (125, 160] < (160, 180] < (180, 200]]

# %%
pd.value_counts(category)
# Out:
# /tmp/ipykernel_754/2654243906.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(category)
# (180, 200]    8
# (160, 180]    3
# (125, 160]    2
# (118, 125]    1
# Name: count, dtype: int64

# %%
bin_names = ['low', 'average', 'high', 'excellent']
pd.cut(marks, bins, labels=bin_names)
# Out:
# ['low', 'average', 'average', 'high', 'high', ..., 'excellent', 'excellent', 'excellent', 'excellent', 'excellent']
# Length: 14
# Categories (4, object): ['low' < 'average' < 'high' < 'excellent']

# %%
pd.cut(np.random.rand(40), 5, precision=2)
# Out:
# [(0.39, 0.57], (0.21, 0.39], (0.76, 0.94], (0.025, 0.21], (0.025, 0.21], ..., (0.57, 0.76], (0.39, 0.57], (0.21, 0.39], (0.025, 0.21], (0.21, 0.39]]
# Length: 40
# Categories (5, interval[float64, right]): [(0.025, 0.21] < (0.21, 0.39] < (0.39, 0.57] <
#                                            (0.57, 0.76] < (0.76, 0.94]]

# %%
randomNumbers = np.random.rand(2000)
category3 = pd.qcut(randomNumbers, 4)
category3
# Out:
# [(-0.000758, 0.251], (0.745, 1.0], (-0.000758, 0.251], (0.251, 0.509], (0.745, 1.0], ..., (-0.000758, 0.251], (0.745, 1.0], (0.745, 1.0], (0.509, 0.745], (-0.000758, 0.251]]
# Length: 2000
# Categories (4, interval[float64, right]): [(-0.000758, 0.251] < (0.251, 0.509] < (0.509, 0.745] <
#                                            (0.745, 1.0]]

# %%
pd.value_counts(category3)
# Out:
# /tmp/ipykernel_754/647498483.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(category3)
# (-0.000758, 0.251]    500
# (0.251, 0.509]        500
# (0.509, 0.745]        500
# (0.745, 1.0]          500
# Name: count, dtype: int64

# %%
df1.head(10)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
# 5           5   2020-06-21 12:15:37    30407675418785
# 6           6   2020-06-21 12:15:44   213180742685905
# 7           7   2020-06-21 12:15:50  3589289942931264
# 8           8   2020-06-21 12:16:10  3596357274378601
# 9           9   2020-06-21 12:16:11  3546897637165774
#
#                                merchant        category     amt     first  \
# 0                 fraud_Kirlin and Sons   personal_care    2.86      Jeff
# 1                  fraud_Sporer-Keebler   personal_care   29.84    Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness   41.28    Ashley
# ...

# %%
df2.head(10)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
# 5           5   2019-01-01 00:04:08  4767265376804500
# 6           6   2019-01-01 00:04:42    30074693890476
# 7           7   2019-01-01 00:05:08  6011360759745864
# 8           8   2019-01-01 00:05:18  4922710831011201
# 9           9   2019-01-01 00:06:01  2720830304681674
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# ...

# %%
df1['fine'] = df1['amt'] * 2.0
df1
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
df2['fine '] = df1['amt']*3.25
df2
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2019-01-01 00:00:18     2703186189652095
# 1                 1   2019-01-01 00:00:44         630423337322
# 2                 2   2019-01-01 00:00:51       38859492057661
# 3                 3   2019-01-01 00:01:16     3534093764340240
# 4                 4   2019-01-01 00:03:06      375534208663984
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# ...

# %%
totalfine = df1["fine"]
totalfine[np.abs(totalfine)>200]
# Out:
# 6         267.86
# 30        352.46
# 31        268.78
# 33        420.72
# 37        269.20
#            ...
# 555683    280.24
# 555696    330.78
# 555705    247.68
# 555707    268.52
# 555715    223.68
# Name: fine, Length: 99985, dtype: float64

# %%
total = df2["fine "]
total[np.abs(total)>200]
# Out:
# 6         435.2725
# 9         216.2550
# 18        260.3575
# 30        572.7475
# 31        436.7675
#             ...
# 555702    268.1575
# 555705    402.4800
# 555707    436.3450
# 555715    363.4800
# 555716    282.3600
# Name: fine , Length: 219491, dtype: float64

# %%
df1[np.abs(totalfine)>300]
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 30              30   2020-06-21 12:25:09   379897244598068
# 33              33   2020-06-21 12:26:23   180036456789979
# 67              67   2020-06-21 12:34:07  3502377050801561
# 71              71   2020-06-21 12:36:17  3590736522064285
# 100            100   2020-06-21 12:45:48  6592074504369261
# ...            ...                   ...               ...
# 555629      555629   2020-12-31 23:26:42  2248735346244816
# 555637      555637   2020-12-31 23:30:29  6011109736646996
# 555647      555647   2020-12-31 23:32:24  6011438889172900
# 555677      555677   2020-12-31 23:42:51     4189814094741
# 555696      555696   2020-12-31 23:50:45  3568255211412877
#
#                         merchant        category      amt      first  \
# 30        fraud_Kautzer and Sons   personal_care   176.23      Frank
# 33              fraud_Nienow PLC   entertainment   210.36  Mackenzie
# ...

# %%
df2[np.abs(total)>400]
# Out:
#         Unnamed: 0 trans_date_trans_time               cc_num  \
# 6                6   2019-01-01 00:04:42       30074693890476
# 30              30   2019-01-01 00:22:36      180094608895855
# 31              31   2019-01-01 00:22:39  4599735407877245080
# 33              33   2019-01-01 00:23:41     2712209726293386
# 37              37   2019-01-01 00:27:45      213141712584544
# ...            ...                   ...                  ...
# 555677      555677   2019-08-25 12:07:04  4653178848915023204
# 555683      555683   2019-08-25 12:09:33      373905417449658
# 555696      555696   2019-08-25 12:12:41     6595970453799027
# 555705      555705   2019-08-25 12:14:28     3596217206093829
# 555707      555707   2019-08-25 12:14:44     4570636521433188
#
#                                     merchant      category     amt      first  \
# 6                      fraud_Rowe-Vandervort   grocery_net   44.54     Kelsey
# ...

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %%
data = {'Age':[25,30,45,32,22], 'Salary':[50000, 64000, 1200000, 85000, 1200000]}
df = pd.DataFrame(data)
print("Orignal data : \n", df, "\n")
# Out:
# Orignal data :
#     Age   Salary
# 0   25    50000
# 1   30    64000
# 2   45  1200000
# 3   32    85000
# 4   22  1200000

# %%
min_max_scaler = MinMaxScaler()
df_min_max = pd.DataFrame(min_max_scaler.fit_transform(df), columns=df.columns)
print("Min-Max Scaled Data:\n", df_min_max, "\n")
# Out:
# Min-Max Scaled Data:
#          Age    Salary
# 0  0.130435  0.000000
# 1  0.347826  0.012174
# 2  1.000000  1.000000
# 3  0.434783  0.030435
# 4  0.000000  1.000000

# %%
standard_scaler = StandardScaler()
df_standard = pd.DataFrame(standard_scaler.fit_transform(df), columns = df.columns)
print("Standardized data:\n", df_standard, "\n")
# Out:
# Standardized data:
#          Age    Salary
# 0 -0.730963 -0.845736
# 1 -0.100823 -0.820533
# 2  1.789600  1.224498
# 3  0.151234 -0.782729
# 4 -1.109048  1.224498
